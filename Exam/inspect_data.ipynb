# %%
import pandas as pd

# %%
df = pd.read_csv('Exam/test_data/challenge_ds.csv')

# %%
df[df['capability'] == 'FreqAdvPresent']
# Out:
#                                             sent      pred  pred_pos  arg_pos  \
# 191        I will be having my birthday tomorrow    having         3        6
# 192        I will be having my birthday tomorrow    having         3        6
# 193           I will be having my birthday today    having         3        6
# 194  I will be having my birthday this afternoon    having         3        6
# 195         I will be having my birthday tonight    having         3        6
# 196                   The concert begins tonight    begins         2        3
# 197                  The concert begins tomorrow    begins         2        3
# 198                     The concert begins today    begins         2        3
# 199            The concert begins this afternoon    begins         2        3
# 200                   The concert begins tonight    begins         2        3
# 201                    Her car is arriving today  arriving         3        4
# ...
