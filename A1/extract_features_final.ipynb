# %% [markdown]
# #### Advanced NLP Assignment 1 - Feature Extraction Code

# %%
# Imports
import spacy, benepar
import pandas as pd
from nltk.corpus import brown, gutenberg
from typing import List, Tuple

# %%
# Load spaCy English language model
nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('benepar', config={'model': 'benepar_en3'})

# Get the text from the Brown Corpus
testing_text = brown.sents(fileids=['ca01'])
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
# Code block written by Furong

# Adding features as follows:
# 1. Token
# 2. Lemma
# 3. PoS tag
# 4. Dependency relation to head
# 5. Head
# 6. Dependents
# 7. Number of dependents

# Initialize an empty list to store the extracted features
features_list = []

# Iterate over all sentences and perform feature extraction
for sentence in testing_text:
    # Combine the tokens into a single sentence
    sentence_text = ' '.join(sentence)
    
    # Perform feature extraction using spaCy
    doc = nlp(sentence_text)

    # Writing features in CoNLL format
    for token in doc:
        # Get dependents as a comma-separated string
        dependents = ', '.join([dep.text for dep in token.children])

        # Use sum() to count the number of dependents
        num_dependents = sum(1 for child in token.children)
            
        ## Create a dictionary to store the features of the token
        token_features = {
            'Token': token.text,
            'Lemma': token.lemma_,
            'POS': token.pos_,
            'Dependency Relation': token.dep_,
            'Head_Text': token.head.text,
            'Dependents': dependents,
            'Num_Dependents': num_dependents
        }
        
        # Append the token features to the list
        features_list.append(token_features)          
        
        # Adding 【lemma of the head word】 as a feature
        # output_file.write(f"{token.text}\t{token.lemma_}\t{token.pos_}\t{token.dep_}\t{token.head.text}\t{token.head.lemma_}\t{dependents}\t{num_dependents}\n")            

        # Adding 【POS of the head word】 as a feature
        # output_file.write(f"{token.text}\t{token.lemma_}\t{token.pos_}\t{token.dep_}\t{token.head.text}\t{token.head.lemma_}\t{token.head.pos_}\t{dependents}\t{num_dependents}\n")
        
# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(features_list)


# Display the DataFrame
display(df)
# Out:
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# c:\Users\nbasa\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\distributions\distribution.py:53: UserWarning: <class 'torch_struct.distributions.TreeCRF'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(
#         Token    Lemma    POS Dependency Relation Head_Text  \
# 0         The      the    DET                 det      Jury
# 1      Fulton   Fulton  PROPN            compound    County
# 2      County   County  PROPN            compound      Jury
# 3       Grand    Grand  PROPN            compound      Jury
# 4        Jury     Jury  PROPN               nsubj      said
# ...       ...      ...    ...                 ...       ...
# 2321      bit      bit   NOUN                attr       was
# 2322       of       of    ADP                prep       bit
# 2323  trouble  trouble   NOUN                pobj        of
# 2324       ''       ''  PUNCT               punct       was
# 2325        .        .  PUNCT               punct       was
#
#               Dependents  Num_Dependents
# 0                                      0
# 1                                      0
# 2                 Fulton               1
# 3                                      0
# 4     The, County, Grand               3
# ...                  ...             ...
# 2321               a, of               2
# 2322             trouble               1
# 2323                                   0
# 2324                                   0
# 2325                                   0
#
# [2326 rows x 7 columns]

# %%
# Testing the above implementation

from spacy import displacy

# Print the the dependency tree to doble check if we get the right dependents in our output CoNLL file

# Process the first sentence with spaCy
sentence_text = ' '.join(testing_text[0])
doc = nlp(sentence_text)

# Visualize the dependency tree using displacy and render to HTML
html_code = displacy.render(doc, style='dep', options={'distance': 100})
# Out:
# c:\Users\nbasa\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\distributions\distribution.py:53: UserWarning: <class 'torch_struct.distributions.TreeCRF'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="adfcbac8cc174a19948664d9f6e4fba2-0" class="displacy" width="2550" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">Fulton</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">County</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Grand</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">Jury</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">said</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Friday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">investigation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">Atlanta</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">recent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">primary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">election</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">produced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">`</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">`</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">evidence ''</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">any</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">irregularities</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">took</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">place .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-adfcbac8cc174a19948664d9f6e4fba2-0-0" stroke-width="2px" d="M70,202.0 C70,52.0 445.0,52.0 445.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-adfcbac8cc174a19948664d9f6e4fba2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-adfcbac8cc174a19948664d9f6e4fba2-0-1" stroke-width="2px" d="M170,202.0 C170,152.0 235.0,152.0 235.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-adfcbac8cc174a19948664d9f6e4fba2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-adfcbac8cc174a19948664d9f6e4fba2-0-2" stroke-width="2px" d="M270,202.0 C270,102.0 440.0,102.0 440.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <t

# %%
# Code block written by Nur

def generate_ngrams(df):
    
    # Forward bigram
    forward_bigram_list = [(df.at[i, 'Token'], df.at[i+1, 'Token']) for i in range(len(df) - 1)]
    # Backward bigram
    backward_bigram_list = [(df.at[i-1, 'Token'], df.at[i, 'Token']) for i in range(1, len(df))]
    
    # Forward trigram
    forward_trigram_list = [(df.at[i, 'Token'], df.at[i+1, 'Token'], df.at[i+2, 'Token']) for i in range(len(df) - 2)]
    # Backward trigram
    backward_trigram_list = [(df.at[i-2, 'Token'], df.at[i-1, 'Token'], df.at[i, 'Token']) for i in range(2, len(df))]

    # Forward POS trigram
    forward_pos_trigram_list = [(df.at[i, 'POS'], df.at[i+1, 'POS'], df.at[i+2, 'POS']) for i in range(len(df) - 2)]
    # Backward POS trigram
    backward_pos_trigram_list = [(df.at[i-2, 'POS'], df.at[i-1, 'POS'], df.at[i, 'POS']) for i in range(2, len(df))]

    # Update df with the generated n-grams
    df['Forward_Bigram'] = forward_bigram_list + [None]
    df['Backward_Bigram'] = [None] + backward_bigram_list
    df['Forward_Trigram'] = forward_trigram_list + [None, None]
    df['Backward_Trigram'] = [None, None] + backward_trigram_list
    df['Forward_POS_Trigram'] = forward_pos_trigram_list + [None, None]
    df['Backward_POS_Trigram'] = [None, None] + backward_pos_trigram_list
    
    return df

df = generate_ngrams(df)
display(df)
# Out:
#         Token    Lemma    POS Dependency Relation Head_Text  \
# 0         The      the    DET                 det      Jury
# 1      Fulton   Fulton  PROPN            compound    County
# 2      County   County  PROPN            compound      Jury
# 3       Grand    Grand  PROPN            compound      Jury
# 4        Jury     Jury  PROPN               nsubj      said
# ...       ...      ...    ...                 ...       ...
# 2321      bit      bit   NOUN                attr       was
# 2322       of       of    ADP                prep       bit
# 2323  trouble  trouble   NOUN                pobj        of
# 2324       ''       ''  PUNCT               punct       was
# 2325        .        .  PUNCT               punct       was
#
#               Dependents  Num_Dependents    Forward_Bigram   Backward_Bigram  \
# 0                                      0     (The, Fulton)              None
# 1                                      0  (Fulton, County)     (The, Fulton)
# 2                 Fulton               1   (County, Grand)  (Fulton, County)
# 3                                      0     (Grand, Jury)   (County, Grand)
# 4     The, County, Grand               3      (Jury, said)     (Grand, Jury)
# ...                  ...             ...               ...               ...
# 2321               a, of               2         (bit, of)          (a, bit)
# 2322             trouble               1     (of, trouble)         (bit, of)
# 2323                                   0     (trouble, '')     (of, trouble)
# 2324                                   0           ('', .)     (trouble, '')
# 2325                                   0              None           ('', .)
#
#               Forward_Trigram         Backward_Trigram    Forward_POS_Trigram  \
# 0       (The, Fulton, County)                     None    (DET, PROPN, PROPN)
# 1     (Fulton, County, Grand)                     None  (PROPN, PROPN, PROPN)
# 2       (County, Grand, Jury)    (The, Fulton, County)  (PROPN, PROPN, PROPN)
# 3         (Grand, Jury, said)  (Fulton, County, Grand)   (PROPN, PROPN, VERB)
# 4        (Jury, said, Friday)    (County, Grand, Jury)   (PROPN, VERB, PROPN)
# ...                       ...                      ...                    ...
# 2321       (bit, of, trouble)            (n't, a, bit)      (NOUN, ADP, NOUN)
# 2322        (of, trouble, '')             (a, bit, of)     (ADP, NOUN, PUNCT)
# 2323         (trouble, '', .)       (bit, of, trouble)   (NOUN, PUNCT, PUNCT)
# 2324                     None        (of, trouble, '')                   None
# 2325                     None         (trouble, '', .)                   None
#
#        Backward_POS_Trigram
# 0                      None
# 1                      None
# 2       (DET, PROPN, PROPN)
# 3     (PROPN, PROPN, PROPN)
# 4     (PROPN, PROPN, PROPN)
# ...                     ...
# 2321      (PART, DET, NOUN)
# 2322       (DET, NOUN, ADP)
# 2323      (NOUN, ADP, NOUN)
# 2324     (ADP, NOUN, PUNCT)
# 2325   (NOUN, PUNCT, PUNCT)
#
# [2326 rows x 13 columns]

# %%
# Code block written by Nur

def get_full_constituent(doc, token):
    """Given a token in a constituency parse tree, extracts the tokens and the POS-tags of its governing constituent.
    :param doc: the spaCy Doc object
    :param token: the token (Word) object in the spaCy Doc
    :return: two lists, one with all tokens in the constituent (str), and one with all POS-tags in the constituent (str)
    """
    # Create lists to be filled with the tokens and POS-tags that are in the constituent
    constituent_tokens = []
    constituent_pos = []

    # Find the token in the Doc object
    for sent in doc.sents:
        for word in sent:
            if word == token:
                # Found the token, get its parent
                parent = word.head
                # Find all children of the parent, add their tokens and POS-tags to constituent_tokens and constituent_pos
                for child in parent.subtree:
                    constituent_tokens.append(child.text.lower())
                    constituent_pos.append(child.pos_)
                break

    return constituent_tokens, constituent_pos

# %%
# Testing the above implementation

text = "The quick brown fox jumps over the lazy dog."

# Process the text with spaCy
doc = nlp(text)

# Choose a token (word) from the processed document
token = doc[0]

# Call the get_whole_constituent function
constituent_tokens, constituent_pos = get_full_constituent(doc, token)

# Print the extracted tokens and POS-tags
print("Tokens in the constituent:", constituent_tokens)
print("POS-tags in the constituent:", constituent_pos)
# Out:
# Tokens in the constituent: ['the', 'quick', 'brown', 'fox']
# POS-tags in the constituent: ['DET', 'ADJ', 'ADJ', 'NOUN']
# c:\Users\nbasa\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\distributions\distribution.py:53: UserWarning: <class 'torch_struct.distributions.TreeCRF'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(

# %%
# Code block written by Furong

# Function to extract verbs as a feature

def extract_verb_token(row):
    if row['POS'] == 'VERB':
        return row['Token']  # Return the token itself if it's a verb
    else:
        return None  # Return None for non-verb tokens

# Apply the function to create a new 'VerbToken' column
df['VerbToken'] = df.apply(extract_verb_token, axis=1)

df.head(50) # works!
# Out:
#              Token          Lemma    POS Dependency Relation       Head_Text  \
# 0              The            the    DET                 det            Jury
# 1           Fulton         Fulton  PROPN            compound          County
# 2           County         County  PROPN            compound            Jury
# 3            Grand          Grand  PROPN            compound            Jury
# 4             Jury           Jury  PROPN               nsubj            said
# 5             said            say   VERB                ROOT            said
# 6           Friday         Friday  PROPN            npadvmod            said
# 7               an             an    DET                 det   investigation
# 8    investigation  investigation   NOUN                dobj            said
# 9               of             of    ADP                prep   investigation
# 10         Atlanta        Atlanta  PROPN                poss        election
# 11              's             's   PART                case         Atlanta
# 12          recent         recent    ADJ                amod        election
# 13         primary        primary    ADJ                amod        election
# 14        election       election   NOUN                pobj              of
# 15        produced        produce   VERB                 acl        election
# 16               `              `  PUNCT               punct        produced
# 17               `              `  PUNCT               punct        produced
# 18              no             no    DET                 det        evidence
# 19        evidence       evidence   NOUN                dobj        produced
# 20              ''             ''  PUNCT               punct        evidence
# 21            that           that  SCONJ                mark            took
# 22             any            any    DET                 det  irregularities
# 23  irregularities   irregularity   NOUN               nsubj            took
# 24            took           take   VERB               relcl        evidence
# 25           place          place   NOUN                dobj            took
# 26               .              .  PUNCT               punct            said
# 27             The            the    DET                 det            jury
# 28            jury           jury   NOUN               nsubj            said
# 29         further            far    ADV              advmod            said
# 30            said            say   VERB                ROOT            said
# 31              in             in    ADP                prep            said
# 32            term           term   NOUN            compound             end
# 33               -              -  PUNCT               punct             end
# 34             end            end   NOUN            compound    presentments
# 35    presentments    presentment   NOUN                pobj              in
# 36            that           that  SCONJ                mark        deserves
# 37             the            the    DET                 det       Committee
# 38            City           City  PROPN            compound       Committee
# 39       Executive      Executive  PROPN            compound       Committee
# 40       Committee      Committee  PROPN               nsubj        deserves
# 41               ,              ,  PUNCT               punct       Committee
# 42           which          which   PRON               nsubj             had
# 43             had           have   VERB               relcl       Committee
# 44            over           over    ADP                nmod          charge
# 45               -              -  PUNCT               punct            over
# 46             all            all   PRON                pobj            over
# 47          charge         charge   NOUN                dobj             had
# 48              of             of    ADP                prep          charge
# 49             the            the    DET                 det        election
#
#                                Dependents  Num_Dependents  \
# 0                                                       0
# 1                                                       0
# 2                                  Fulton               1
# 3                                                       0
# 4                      The, County, Grand               3
# 5          Jury, Friday, investigation, .               4
# 6                                                       0
# 7                                                       0
# 8                                  an, of               2
# 9                                election               1
# 10                                     's               1
# 11                                                      0
# 12                                                      0
# 13                                                      0
# 14     Atlanta, recent, primary, produced               4
# 15                         `, `, evidence               3
# 16                                                      0
# 17                                                      0
# 18                                                      0
# 19                           no, '', took               3
# 20                                                      0
# 21                                                      0
# 22                                                      0
# 23                                    any               1
# 24            that, irregularities, place               3
# 25                                                      0
# 26                                                      0
# 27                                                      0
# 28                                    The               1
# 29                                                      0
# 30         jury, further, in, deserves, .               5
# 31                           presentments               1
# 32                                                      0
# 33                                                      0
# 34                                term, -               2
# 35                                    end               1
# 36                                                      0
# 37                                                      0
# 38                                                      0
# 39                                                      0
# 40  the, City, Executive, ,, had, ,, `, `               8
# 41                                                      0
# 42                                                      0
# 43                          which, charge               2
# 44                                 -, all               2
# 45                                                      0
# 46                                                      0
# 47                               over, of               2
# 48                               election               1
# 49                                                      0
#
#             Forward_Bigram         Backward_Bigram  \
# 0            (The, Fulton)                    None
# 1         (Fulton, County)           (The, Fulton)
# 2          (County, Grand)        (Fulton, County)
# 3            (Grand, Jury)         (County, Grand)
# 4             (Jury, said)           (Grand, Jury)
# 5           (said, Friday)            (Jury, said)
# 6             (Friday, an)          (said, Friday)
# 7      (an, investigation)            (Friday, an)
# 8      (investigation, of)     (an, investigation)
# 9            (of, Atlanta)     (investigation, of)
# 10           (Atlanta, 's)           (of, Atlanta)
# 11            ('s, recent)           (Atlanta, 's)
# 12       (recent, primary)            ('s, recent)
# 13     (primary, election)       (recent, primary)
# 14    (election, produced)     (primary, election)
# 15           (produced, `)    (election, produced)
# 16                  (`, `)           (produced, `)
# 17                 (`, no)                  (`, `)
# 18          (no, evidence)                 (`, no)
# 19          (evidence, '')          (no, evidence)
# 20              ('', that)          (evidence, '')
# 21             (that, any)              ('', that)
# 22   (any, irregularities)             (that, any)
# 23  (irregularities, took)   (any, irregularities)
# 24           (took, place)  (irregularities, took)
# 25              (place, .)           (took, place)
# 26                (., The)              (place, .)
# 27             (The, jury)                (., The)
# 28         (jury, further)             (The, jury)
# 29         (further, said)         (jury, further)
# 30              (said, in)         (further, said)
# 31              (in, term)              (said, in)
# 32               (term, -)              (in, term)
# 33                (-, end)               (term, -)
# 34     (end, presentments)                (-, end)
# 35    (presentments, that)     (end, presentments)
# 36             (that, the)    (presentments, that)
# 37             (the, City)             (that, the)
# 38       (City, Executive)             (the, City)
# 39  (Executive, Committee)       (City, Executive)
# 40          (Committee, ,)  (Executive, Committee)
# 41              (,, which)          (Committee, ,)
# 42            (which, had)              (,, which)
# 43             (had, over)            (which, had)
# 44               (over, -)             (had, over)
# 45                (-, all)               (over, -)
# 46           (all, charge)                (-, all)
# 47            (charge, of)           (all, charge)
# 48               (of, the)            (charge, of)
# 49         (the, election)               (of, the)
#
#                   Forward_Trigram               Backward_Trigram  \
# 0           (The, Fulton, County)                           None
# 1         (Fulton, County, Grand)                           None
# 2           (County, Grand, Jury)          (The, Fulton, County)
# 3             (Grand, Jury, said)        (Fulton, County, Grand)
# 4            (Jury, said, Friday)          (County, Grand, Jury)
# 5              (said, Friday, an)            (Grand, Jury, said)
# 6     (Friday, an, investigation)           (Jury, said, Friday)
# 7         (an, investigation, of)             (said, Friday, an)
# 8    (investigation, of, Atlanta)    (Friday, an, investigation)
# 9               (of, Atlanta, 's)        (an, investigation, of)
# 10          (Atlanta, 's, recent)   (investigation, of, Atlanta)
# 11          ('s, recent, primary)              (of, Atlanta, 's)
# 12    (recent, primary, election)          (Atlanta, 's, recent)
# 13  (primary, election, produced)          ('s, recent, primary)
# 14        (election, produced, `)    (recent, primary, election)
# 15               (produced, `, `)  (primary, election, produced)
# 16                     (`, `, no)        (election, produced, `)
# 17              (`, no, evidence)               (produced, `, `)
# 18             (no, evidence, '')                     (`, `, no)
# 19           (evidence, '', that)              (`, no, evidence)
# 20                ('', that, any)             (no, evidence, '')
# 21    (that, any, irregularities)           (evidence, '', that)
# 22    (any, irregularities, took)                ('', that, any)
# 23  (irregularities, took, place)    (that, any, irregularities)
# 24               (took, place, .)    (any, irregularities, took)
# 25                (place, ., The)  (irregularities, took, place)
# 26                 (., The, jury)               (took, place, .)
# 27           (The, jury, further)                (place, ., The)
# 28          (jury, further, said)                 (., The, jury)
# 29            (further, said, in)           (The, jury, further)
# 30               (said, in, term)          (jury, further, said)
# 31                  (in, term, -)            (further, said, in)
# 32                 (term, -, end)               (said, in, term)
# 33         (-, end, presentments)                  (in, term, -)
# 34      (end, presentments, that)                 (term, -, end)
# 35      (presentments, that, the)         (-, end, presentments)
# 36              (that, the, City)      (end, presentments, that)
# 37         (the, City, Executive)      (presentments, that, the)
# 38   (City, Executive, Committee)              (that, the, City)
# 39      (Executive, Committee, ,)         (the, City, Executive)
# 40          (Committee, ,, which)   (City, Executive, Committee)
# 41                (,, which, had)      (Executive, Committee, ,)
# 42             (which, had, over)          (Committee, ,, which)
# 43                 (had, over, -)                (,, which, had)
# 44                 (over, -, all)             (which, had, over)
# 45               (-, all, charge)                 (had, over, -)
# 46              (all, charge, of)                 (over, -, all)
# 47              (charge, of, the)               (-, all, charge)
# 48            (of, the, election)              (all, charge, of)
# 49             (the, election, ,)              (charge, of, the)
#
#       Forward_POS_Trigram   Backward_POS_Trigram VerbToken
# 0     (DET, PROPN, PROPN)                   None      None
# 1   (PROPN, PROPN, PROPN)                   None      None
# 2   (PROPN, PROPN, PROPN)    (DET, PROPN, PROPN)      None
# 3    (PROPN, PROPN, VERB)  (PROPN, PROPN, PROPN)      None
# 4    (PROPN, VERB, PROPN)  (PROPN, PROPN, PROPN)      None
# 5      (VERB, PROPN, DET)   (PROPN, PROPN, VERB)      said
# 6      (PROPN, DET, NOUN)   (PROPN, VERB, PROPN)      None
# 7        (DET, NOUN, ADP)     (VERB, PROPN, DET)      None
# 8      (NOUN, ADP, PROPN)     (PROPN, DET, NOUN)      None
# 9      (ADP, PROPN, PART)       (DET, NOUN, ADP)      None
# 10     (PROPN, PART, ADJ)     (NOUN, ADP, PROPN)      None
# 11       (PART, ADJ, ADJ)     (ADP, PROPN, PART)      None
# 12       (ADJ, ADJ, NOUN)     (PROPN, PART, ADJ)      None
# 13      (ADJ, NOUN, VERB)       (PART, ADJ, ADJ)      None
# 14    (NOUN, VERB, PUNCT)       (ADJ, ADJ, NOUN)      None
# 15   (VERB, PUNCT, PUNCT)      (ADJ, NOUN, VERB)  produced
# 16    (PUNCT, PUNCT, DET)    (NOUN, VERB, PUNCT)      None
# 17     (PUNCT, DET, NOUN)   (VERB, PUNCT, PUNCT)      None
# 18     (DET, NOUN, PUNCT)    (PUNCT, PUNCT, DET)      None
# 19   (NOUN, PUNCT, SCONJ)     (PUNCT, DET, NOUN)      None
# 20    (PUNCT, SCONJ, DET)     (DET, NOUN, PUNCT)      None
# 21     (SCONJ, DET, NOUN)   (NOUN, PUNCT, SCONJ)      None
# 22      (DET, NOUN, VERB)    (PUNCT, SCONJ, DET)      None
# 23     (NOUN, VERB, NOUN)     (SCONJ, DET, NOUN)      None
# 24    (VERB, NOUN, PUNCT)      (DET, NOUN, VERB)      took
# 25     (NOUN, PUNCT, DET)     (NOUN, VERB, NOUN)      None
# 26     (PUNCT, DET, NOUN)    (VERB, NOUN, PUNCT)      None
# 27       (DET, NOUN, ADV)     (NOUN, PUNCT, DET)      None
# 28      (NOUN, ADV, VERB)     (PUNCT, DET, NOUN)      None
# 29       (ADV, VERB, ADP)       (DET, NOUN, ADV)      None
# 30      (VERB, ADP, NOUN)      (NOUN, ADV, VERB)      said
# 31     (ADP, NOUN, PUNCT)       (ADV, VERB, ADP)      None
# 32    (NOUN, PUNCT, NOUN)      (VERB, ADP, NOUN)      None
# 33    (PUNCT, NOUN, NOUN)     (ADP, NOUN, PUNCT)      None
# 34    (NOUN, NOUN, SCONJ)    (NOUN, PUNCT, NOUN)      None
# 35     (NOUN, SCONJ, DET)    (PUNCT, NOUN, NOUN)      None
# 36    (SCONJ, DET, PROPN)    (NOUN, NOUN, SCONJ)      None
# 37    (DET, PROPN, PROPN)     (NOUN, SCONJ, DET)      None
# 38  (PROPN, PROPN, PROPN)    (SCONJ, DET, PROPN)      None
# 39  (PROPN, PROPN, PUNCT)    (DET, PROPN, PROPN)      None
# 40   (PROPN, PUNCT, PRON)  (PROPN, PROPN, PROPN)      None
# 41    (PUNCT, PRON, VERB)  (PROPN, PROPN, PUNCT)      None
# 42      (PRON, VERB, ADP)   (PROPN, PUNCT, PRON)      None
# 43     (VERB, ADP, PUNCT)    (PUNCT, PRON, VERB)       had
# 44     (ADP, PUNCT, PRON)      (PRON, VERB, ADP)      None
# 45    (PUNCT, PRON, NOUN)     (VERB, ADP, PUNCT)      None
# 46      (PRON, NOUN, ADP)     (ADP, PUNCT, PRON)      None
# 47       (NOUN, ADP, DET)    (PUNCT, PRON, NOUN)      None
# 48       (ADP, DET, NOUN)      (PRON, NOUN, ADP)      None
# 49     (DET, NOUN, PUNCT)       (NOUN, ADP, DET)      None

# %%
# Code block written by Martin

def leading_advb(head):
    """  The index of the span containing a leading Adverbial Phrase
    """
    if not list(head._.children):
        return []
    span_idx: List[Tuple] = []
    if len(list(head._.children)[0]._.labels) and 'ADVP' in list(head._.children)[0]._.labels[0]:
        span_idx.append((list(head._.children)[0].start_char, list(head._.children)[0].end_char))
    else:
        for child in head._.children:
            span_idx += leading_advb(child)
    return span_idx
    
def find_gvb_as_np(head, is_np=False):
    """ The index of the span containing a Verb Gerundive Phrase as 
    part of a Noun Phrase
    """
    # No children so no point in checking
    if not list(head._.children):
        return []
    span_idx: List[Tuple] = []
    is_np = True if 'NP' in head._.labels else is_np
    if 'VP' in head._.labels and is_np:
        for child in head._.children:
            if 'VBG' in child._.labels or 'VBG' in child._.parse_string:
                span_idx.append((head.start_char, head.end_char))
                break
    else:
        for child in head._.children:
            span_idx += find_gvb_as_np(child, is_np)
    return span_idx
        
def find_parenthetical(head):
    """ The index of the span containing a Parenthetical
    """
    # No children so no point in checking
    if not list(head._.children):
        return [] 
    # List of tuples (i, j) of index
    span_idx: List[Tuple] = []
    # Since it's not an NP, we need to check the children to see 
    # if we get to onne
    if 'NP' not in head._.labels:
        # Recursively check the children
        for child in head._.children:
            span_idx = span_idx + find_parenthetical(child)
    # Its an NP so then we check if it is possible that 
    # it contains a Parenthetical
    else: 
        for i, node in enumerate(head._.children):
            if 'PRN' in node._.labels:
                span_idx.append((node.start_char, node.end_char))
    return span_idx 

def find_npa(head):
    """ The index of the span containing a Noun Phrase Appositive
    """
    # No children so no point in checking
    if not head._.children:
        return [] 
    # List of tuples (i, j) of index
    npa_idx: List[Tuple] = []
    # Since it's not an NP, we need to check the children to see 
    # if we get to onne
    if 'NP' not in head._.labels:
        # Recursively check the children
        for child in head._.children:
            npa_idx = npa_idx + find_npa(child)
    # Its an NP so then we check if it is possible that 
    # its formed by NPs in which one is an appositive
    else: 
        for i, node in enumerate(head._.children):
            # First node cannot be appostiive
            if i == 0:
                continue
            if 'NP' in node._.labels:
                if list(head._.children)[i-1].text == ',':
                    npa_idx.append((node.start_char, node.end_char))
                    break
    return npa_idx

def parse_sentences(lines: List):
    df_dict = {
        'is_npa': [],
        'is_parenthetical': [],
        'is_gvb_as_np': [],
        'is_leading_advb': [],
        'token_id': [],
        'sentence_num': [],
        'word': [],
    }
    
    for sent_id, sent in enumerate(lines):
        doc = nlp(sent)

        npa_span_idx = find_npa(list(doc.sents)[0])
        parenthetical_span_idx = find_parenthetical(list(doc.sents)[0])
        gvb_as_np_span_idx = find_gvb_as_np(list(doc.sents)[0])
        leading_advb_span_idx = leading_advb(list(doc.sents)[0])

        for token_id, token in enumerate(list(doc.sents)[0]):
            is_npa = False
            is_parenthetical = False
            is_gvb_as_np = False
            is_leading_advb = False

            start_i = token.idx
            end_i = start_i + len(token.text)

            for span_i in npa_span_idx:
                if start_i >= span_i[0] and end_i <= span_i[1]:
                    is_npa = True
                    break
            for span_i in parenthetical_span_idx:
                if start_i >= span_i[0] and end_i <= span_i[1]:
                    is_parenthetical = True
                    break
            for span_i in gvb_as_np_span_idx:
                if start_i >= span_i[0] and end_i <= span_i[1]:
                    is_gvb_as_np = True
                    break
            for span_i in leading_advb_span_idx:
                if start_i >= span_i[0] and end_i <= span_i[1]:
                    is_leading_advb = True
                    break

            df_dict['is_npa'].append(is_npa)
            df_dict['is_parenthetical'].append(is_parenthetical)
            df_dict['is_gvb_as_np'].append(is_gvb_as_np)
            df_dict['is_leading_advb'].append(is_leading_advb)

            df_dict['token_id'].append(token_id)
            df_dict['sentence_num'].append(sent_id)
            df_dict['word'].append(token.text)

    df = pd.DataFrame(df_dict)
    return df

# %%
# Testing the above implementation

def load_data():
    new_lines = []
    for gutenberg_file in gutenberg.fileids():
        lines = gutenberg.sents(gutenberg_file)
        for line in lines:
            line = ' '.join(line)
            new_lines.append(line)
        break
    return new_lines

lines = load_data()
new_df = parse_sentences(lines)

new_df.head(100)
